# %%
name = "Вика"
print("Привет, " + name)
print("как прошел твой день, " + name)
print("что ты сегодня ел, " + name)
# Out:
# Привет, Вика
# как прошел твой день, Вика
# что ты сегодня ел, Вика

# %%
name = "Дима"
name = "Саша"
name = "Вика"
name = 10
random_bool = True
random_bool_2 = False
print(name)
print(random_bool)
print(random_bool_2)
# Out:
# 10
# True
# False

# %%
weekDays = [
	"0Понедельник-1 -7",
	"1Вторник-2",
	"2Среда-3",
	"3Четверг-4",
	"4Пятница-5",
	"5Суббота-6",
	"6Воскресенье-1"
]
lenght = len(weekDays)
print(lenght, end= ' ')

monday = weekDays[-7]
print(monday)
# Out:
# 7 0Понедельник-1 -7

# %%
def sumNumbers(a, b):
		print(a+b)

sumNumbers(5, 6)

# %%
def greet(name):
	print("Привет," + name)

greet("Alex")
# Out:
# 11

# %%
def greet(name):
	print("Привет," + name)

greet("Alex")
greet("Mark")
# Out:
# Привет,Alex
# Привет,Mark

# %%
globalVar = 1

def printGlobal():
	print(globalVar)

printGlobal()



def printlocal():
    local = 2
    print(local)

printlocal()
# Out:
# 1
# 2

# %%
def funcA():
	print("Начали делать А")
	funcB()
	print("Закончили делать А")

def funcB():
	print("Начали делать В")
	funcC()
	print("Закончили делать В")

def funcC():
	print("Начали делать С")
	funcD()
	print("Закончили делать С")

def funcD():
	print("Сделали D")

print("Начали программу")
funcA()
print("Закончили программу")
# Out:
# Начали программу
# Начали делать А
# Начали делать В
# Начали делать С
# Сделали D
# Закончили делать С
# Закончили делать В
# Закончили делать А
# Закончили программу
