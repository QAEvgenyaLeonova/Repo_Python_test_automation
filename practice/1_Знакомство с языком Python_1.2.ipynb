# %%
my_heigh = 165
print(my_heigh)
# Out:
# 165

# %%
my_name = 'Женя'
my_name = 'Леонова'
print(my_name)
# Out:
# Леонова

# %%
pet_name = input("Как зовут вашего питомца? ")
print(pet_name)
# Out:
# вава

# %%
def print_python():
    print("Учу Python!")

print_python()
# Out:
# Учу Python!

# %%
def print_letter(let):
    print(let, end='')


print_letter('S')
print_letter('k')
print_letter('y')
print_letter('P')
print_letter('r')
print_letter('o')
# Out:
# SkyPro
