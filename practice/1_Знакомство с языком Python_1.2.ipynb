# %%
my_heigh = 165
print(my_heigh)
# Out:
# 165

# %%
my_name = 'Женя'
my_name = 'Леонова'
print(my_name)
# Out:
# Леонова

# %%
pet_name = input('Как звать питомца?')
print(f'Питомца звать: {pet_name}')
print('Питомца звать: ' + pet_name)
# Out:
# Питомца звать : rtrt
# Питомца звать: rtrt

# %%
def print_python():
    print('Учу Пайтон!')

print_python()
# Out:
# Учу Пайтон!

# %%
def student_1(st_1):
    print(st_1, end= '')

student_1('м')
student_1('и')
student_1('р')
# Out:
# мир
