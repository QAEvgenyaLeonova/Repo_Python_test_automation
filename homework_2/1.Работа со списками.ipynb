# %%
lst = ['grape', 'peach', 'pear', 'tangerine', 'banana', 'apple']

fruit_1 = lst[0]
fruit_6 = lst[-1]

print(f'Первый вкусный фрукт: {fruit_1} и последний вкусный фрукт: {fruit_6}')
# Out:
# Первый вкусный фрукт: grape и последний вкусный фрукт: apple
